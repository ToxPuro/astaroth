# %%
import os
#TFM coeffs plotting and debugging notebook
#Roberts without SOCA
os.chdir("/scratch/project_462000509/mkorpi/tfm-mpi/Roberts/test6/")
#Roberts with SOCA
#os.chdir("/scratch/project_462000509/mkorpi/tfm-mpi/Roberts/test7/")
# %run /projappl/project_462000509/mkorpi/astaroth-tfm/astaroth/samples/tfm-mpi/tfm_coeffs.py --inputs *.profile
# Out:
# Creating output directory at output
# alp0,eta0,rm,t,nzz -0.026138613861386138 0.005227722772277227 3.1366336633663368 349.4151 101

# %%
test1=sinz*emf11x
test2=cosz*emf12x

# %%
test3=sinz*emf21x
test4=cosz*emf22x

# %%
test5=sinz*emf21y
test6=cosz*emf12y

# %%
test7=sinz*emf21y
test8=cosz*emf22y

# %%
i=100
plt.plot(z,test1[i,:],label="sinz*emf11x")
plt.plot(z,test2[i,:],label="cosz*emf12x")
plt.plot(z,test3[i,:],label="sinz*emf21x")
plt.plot(z,test4[i,:],label="cosz*emf22x")
plt.plot(z,test5[i,:],label="sinz*emf21y")
plt.plot(z,test6[i,:],label="sinz*emf12y")
plt.plot(z,test7[i,:],label="sinz*emf11y")
plt.plot(z,test8[i,:],label="sinz*emf12y")
plt.axhline(y=0.0, color='r', linestyle='dashed')
plt.legend()
plt.show()

# %%
plt.plot(z,300.*emf11x[i,:],label="emf11x")
plt.plot(z,300.*emf12x[i,:],label="emf12x")
plt.plot(z,300.*emf21x[i,:],label="emf21x")
plt.plot(z,300.*emf22x[i,:],label="emf22x")
plt.plot(z,cosz,label='cos')
plt.plot(z,sinz,label="sin")
plt.axhline(y=0.0, color='r', linestyle='dashed')
plt.legend()
plt.show()

# %%
print(dz)
print(z)
print(sinz)
# Out:
# 0.03125
# [0.015625 0.046875 0.078125 0.109375 0.140625 0.171875 0.203125 0.234375
#  0.265625 0.296875 0.328125 0.359375 0.390625 0.421875 0.453125 0.484375
#  0.515625 0.546875 0.578125 0.609375 0.640625 0.671875 0.703125 0.734375
#  0.765625 0.796875 0.828125 0.859375 0.890625 0.921875 0.953125 0.984375]
# [ 0.09801714  0.29028468  0.47139674  0.63439328  0.77301045  0.88192126
#   0.95694034  0.99518473  0.99518473  0.95694034  0.88192126  0.77301045
#   0.63439328  0.47139674  0.29028468  0.09801714 -0.09801714 -0.29028468
#  -0.47139674 -0.63439328 -0.77301045 -0.88192126 -0.95694034 -0.99518473
#  -0.99518473 -0.95694034 -0.88192126 -0.77301045 -0.63439328 -0.47139674
#  -0.29028468 -0.09801714]

# %%
plt.plot(z,300.*emf11y[i,:],label="emf11y")
plt.plot(z,300.*emf12y[i,:],label="emf12y")
plt.plot(z,300.*emf21y[i,:],label="emf21y")
plt.plot(z,300.*emf22y[i,:],label="emf22y")
plt.plot(z,cosz,label='cos')
plt.plot(z,sinz,label="sin")
plt.axhline(y=0.0, color='r', linestyle='dashed')
plt.legend()
plt.show()

# %%
plt.plot(z,B11_x[10,:])
plt.plot(z,B22_y[10,:])
plt.axhline(y=0.0, color='r', linestyle='dashed')
